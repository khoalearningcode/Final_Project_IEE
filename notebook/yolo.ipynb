# %% [markdown]
# # Clone YOLOv8 source code

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 61497, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 61497 (delta 11), reused 18 (delta 6), pack-reused 61457 (from 1)
# Receiving objects: 100% (61497/61497), 33.55 MiB | 30.84 MiB/s, done.
# Resolving deltas: 100% (45765/45765), done.

# %% [markdown]
# # Download required packages

# %%
# !pip install ultralytics
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6411.4/8062.4 GB disk)

# %%
# # Or use this way
# %cd ultralytics
# !pip install -e

# %% [markdown]
# # Download pretrained models

# %% [markdown]
# Should use YOLOv8s

# %%
# %cd ultralytics
# !wget https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12m.pt
# Out:
# /kaggle/working/ultralytics
# --2025-08-09 03:32:55--  https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12m.pt
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd ../
# Out:
# /kaggle/working

# %% [markdown]
# # Download dataset

# %%
# !gdown --id 1--0QuKMwj31K-CSvD8oq5fceFweiFPuN

# %%
# !unzip /content/human_detection_dataset.zip

# %% [markdown]
# # Prepare .yaml file

# %% [markdown]
# # Training

# %%
# !mkdir -p /kaggle/working/dataset/images/train
# !mkdir -p /kaggle/working/dataset/images/val
# !mkdir -p /kaggle/working/dataset/labels/train
# !mkdir -p /kaggle/working/dataset/labels/val

# !cp /kaggle/input/data-train/Data/Image/Train_50/* /kaggle/working/dataset/images/train/
# !cp /kaggle/input/data-train/Data/Image/Valid_50/* /kaggle/working/dataset/images/val/
# !cp /kaggle/input/data-train/Data/Label/train/* /kaggle/working/dataset/labels/train/
# !cp /kaggle/input/data-train/Data/Label/val/* /kaggle/working/dataset/labels/val/

# %%
import yaml

dataset_info = {
    'train': '/kaggle/working/dataset/images/train',
    'val': '/kaggle/working/dataset/images/val',
    'nc': 7,
    'names': ["Cấm ngược chiều","Cấm dừng và đỗ", "Cấm rẽ", "Giới hạn tốc độ", "Cấm còn lại", "Nguy hiểm", "Hiệu lệnh"]
}

with open('/kaggle/working/ultralytics/data.yaml', 'w') as f:
    yaml.dump(dataset_info, f)

# %%
# !pwd
# Out:
# /kaggle/working/ultralytics

# %%
# !yolo train model=/kaggle/working/ultralytics/yolo12m.pt data=/kaggle/working/ultralytics/data.yaml epochs=100 imgsz=640 batch=16 device=0  patience=20
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # Predict

# %%
# !yolo predict model=/kaggle/working/ultralytics/runs/detect/train2/weights/best.pt source=/kaggle/input/traffic-sign-detection-zalo-challenge-2020/traffic_public_test/traffic_public_test/images
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12s summary (fused): 159 layers, 9,233,589 parameters, 0 gradients, 21.2 GFLOPs
#
# image 1/586 /kaggle/input/traffic-sign-detection-zalo-challenge-2020/traffic_public_test/traffic_public_test/images/0.png: 256x640 1 Cấm dừng và đỗ, 49.5ms
# image 2/586 /kaggle/input/traffic-sign-detection-zalo-challenge-2020/traffic_public_test/traffic_public_test/images/100.png: 256x640 1 Cấm dừng và đỗ, 14.1ms
# image 3/586 /kaggle/input/traffic-sign-detection-zalo-challenge-2020/traffic_public_test/traffic_public_test/images/10013.png: 256x640 1 Cấm ngược chiều, 13.9ms
# image 4/586 /kaggle/input/traffic-sign-detection-zalo-challenge-2020/traffic_public_test/traffic_public_test/images/10048.png: 256x640 (no detections), 13.9ms
# image 5/586 /kaggle/input/traffic-sign-detection-zalo-challenge-2020/traffic_public_test/traffic_public_test/images/10053.png: 256x640 1 Cấm dừng và đỗ, 14.3ms
# ...

# %%
# Nén folder predict thành file zip
# !zip -r train_12s.zip /kaggle/working/ultralytics/runs/detect/train2
# Out:
#   adding: kaggle/working/ultralytics/runs/detect/train2/ (stored 0%)
#   adding: kaggle/working/ultralytics/runs/detect/train2/args.yaml (deflated 53%)
#   adding: kaggle/working/ultralytics/runs/detect/train2/train_batch1.jpg (deflated 11%)
#   adding: kaggle/working/ultralytics/runs/detect/train2/val_batch2_pred.jpg (deflated 9%)
#   adding: kaggle/working/ultralytics/runs/detect/train2/confusion_matrix.png (deflated 20%)
#   adding: kaggle/working/ultralytics/runs/detect/train2/train_batch2.jpg (deflated 10%)
#   adding: kaggle/working/ultralytics/runs/detect/train2/BoxF1_curve.png (deflated 8%)
#   adding: kaggle/working/ultralytics/runs/detect/train2/val_batch1_labels.jpg (deflated 9%)
#   adding: kaggle/working/ultralytics/runs/detect/train2/weights/ (stored 0%)
#   adding: kaggle/working/ultralytics/runs/detect/train2/weights/last.pt (deflated 8%)
#   adding: kaggle/working/ultralytics/runs/detect/train2/weights/best.pt (deflated 8%)
# ...

# %%
# Nén folder predict thành file zip
# !zip -r predict_12s.zip /kaggle/working/ultralytics/runs/detect/predict2
# Out:
#   adding: kaggle/working/ultralytics/runs/detect/predict2/ (stored 0%)
#   adding: kaggle/working/ultralytics/runs/detect/predict2/1230.jpg (deflated 0%)
#   adding: kaggle/working/ultralytics/runs/detect/predict2/12379.jpg (deflated 0%)
#   adding: kaggle/working/ultralytics/runs/detect/predict2/12206.jpg (deflated 0%)
#   adding: kaggle/working/ultralytics/runs/detect/predict2/835.jpg (deflated 0%)
#   adding: kaggle/working/ultralytics/runs/detect/predict2/8303.jpg (deflated 0%)
#   adding: kaggle/working/ultralytics/runs/detect/predict2/11373.jpg (deflated 0%)
#   adding: kaggle/working/ultralytics/runs/detect/predict2/6737.jpg (deflated 0%)
#   adding: kaggle/working/ultralytics/runs/detect/predict2/11249.jpg (deflated 1%)
#   adding: kaggle/working/ultralytics/runs/detect/predict2/1829.jpg (deflated 1%)
#   adding: kaggle/working/ultralytics/runs/detect/predict2/740.jpg (deflated 0%)
#   adding: kaggle/working/ultralytics/runs/detect/predict2/10545.jpg (deflated 0%)
# ...

# %%
# # With uploaded image
# !yolo predict model=yolov8s.pt source=filepath

# # With online image
# !yolo predict model=yolov8s.pt source=online_img_url

# # With youtube video
# !yolo predict model=yolov8s.pt source=youtube_video_url

# %% [markdown]
# # Export model (Optional)

# %%
# Nén folder predict thành file zip
# !zip -r train4.zip /kaggle/working/ultralytics/runs/detect/train4

# %%
# !yolo export model=/kaggle/working/ultralytics/runs/detect/train2/weights/best.pt format=onnx
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLOv12s summary (fused): 159 layers, 9,233,589 parameters, 0 gradients, 21.2 GFLOPs
#
# PyTorch: starting from '/kaggle/working/ultralytics/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 11, 8400) (18.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<1.18.0', 'onnxslim>=0.1.59', 'onnxruntime'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 9.2s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.64...
# ONNX: export success ✅ 14.9s, saved as '/kaggle/working/ultralytics/runs/detect/train2/weights/best.onnx' (35.5 MB)
#
# Export complete (16.0s)
# ...
